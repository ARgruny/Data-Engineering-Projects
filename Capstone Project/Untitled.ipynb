# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")

# %%
msft
# Out:
# yfinance.Ticker object <MSFT>

# %%
hist = msft.history(period="max")

# %%
msft.cashflow
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
msft.earnings
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
msft.options
# Out:
# ('2020-05-01',
#  '2020-05-08',
#  '2020-05-15',
#  '2020-05-22',
#  '2020-05-29',
#  '2020-06-05',
#  '2020-06-19',
#  '2020-07-17',
#  '2020-09-18',
#  '2020-10-16',
#  '2020-12-18',
#  '2021-01-15',
#  '2021-03-19',
#  '2021-06-18',
#  '2021-09-17',
#  '2022-01-21',
#  '2022-03-18',
#  '2022-06-17',
#  '2022-09-16')

# %%
opt = msft.option_chain('2020-05-01')

# %%
opt.calls
# Out:
#          contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0   MSFT200501C00100000 2020-04-23 19:17:20   100.0      72.00  73.60  73.85
# 1   MSFT200501C00105000 2020-03-27 14:15:21   105.0      46.90  68.10  70.65
# 2   MSFT200501C00110000 2020-04-14 14:00:15   110.0      60.68  63.60  64.15
# 3   MSFT200501C00113000 2020-03-30 04:07:42   113.0      39.25  60.65  61.00
# 4   MSFT200501C00115000 2020-04-20 16:40:56   115.0      63.13  58.55  59.15
# 5   MSFT200501C00117000 2020-04-23 15:11:46   117.0      57.00  56.55  57.30
# 6   MSFT200501C00120000 2020-04-27 16:13:46   120.0      54.80  53.60  54.35
# 7   MSFT200501C00123000 2020-03-25 19:05:02   123.0      32.09  50.10  52.70
# 8   MSFT200501C00124000 2020-03-24 22:30:51   124.0      19.85  47.60  48.65
# 9   MSFT200501C00125000 2020-04-21 18:32:12   125.0      45.74  48.30  49.25
# 10  MSFT200501C00127000 2020-03-30 04:07:42   127.0      26.00  46.55  47.25
# ...
